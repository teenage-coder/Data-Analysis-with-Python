# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('summer.csv').dropna()

# %%
df.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
len(df)
# Out:
# 31161

# %%
df['City'].describe()
# Out:
# count      31161
# unique        22
# top       London
# freq        3563
# Name: City, dtype: object

# %%
df['Sport'].describe()
# Out:
# count        31161
# unique          43
# top       Aquatics
# freq          4170
# Name: Sport, dtype: object

# %%
df['Discipline'].describe()
# Out:
# count         31161
# unique           67
# top       Athletics
# freq           3637
# Name: Discipline, dtype: object

# %%
df['Country'].describe()
# Out:
# count     31161
# unique      147
# top         USA
# freq       4585
# Name: Country, dtype: object

# %%
df['Athlete'].describe()
# Out:
# count               31161
# unique              22761
# top       PHELPS, Michael
# freq                   22
# Name: Athlete, dtype: object

# %%
df['Gender'].describe()
# Out:
# count     31161
# unique        2
# top         Men
# freq      22744
# Name: Gender, dtype: object

# %%
df['Event'].describe()
# Out:
# count        31161
# unique         666
# top       Football
# freq          1497
# Name: Event, dtype: object

# %%
df['Medal'].describe()
# Out:
# count     31161
# unique        3
# top        Gold
# freq      10484
# Name: Medal, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31161 entries, 0 to 31164
# Data columns (total 9 columns):
# Year          31161 non-null int64
# City          31161 non-null object
# Sport         31161 non-null object
# Discipline    31161 non-null object
# Athlete       31161 non-null object
# Country       31161 non-null object
# Gender        31161 non-null object
# Event         31161 non-null object
# Medal         31161 non-null object
# dtypes: int64(1), object(8)
# memory usage: 2.4+ MB

# %%
df[df['Athlete'] == 'PHELPS, Michael']
# Out:
#        Year     City     Sport Discipline          Athlete Country Gender  \
# 25225  2004   Athens  Aquatics   Swimming  PHELPS, Michael     USA    Men
# 25253  2004   Athens  Aquatics   Swimming  PHELPS, Michael     USA    Men
# 25258  2004   Athens  Aquatics   Swimming  PHELPS, Michael     USA    Men
# 25265  2004   Athens  Aquatics   Swimming  PHELPS, Michael     USA    Men
# 25277  2004   Athens  Aquatics   Swimming  PHELPS, Michael     USA    Men
# 25286  2004   Athens  Aquatics   Swimming  PHELPS, Michael     USA    Men
# 25325  2004   Athens  Aquatics   Swimming  PHELPS, Michael     USA    Men
# 25361  2004   Athens  Aquatics   Swimming  PHELPS, Michael     USA    Men
# 27224  2008  Beijing  Aquatics   Swimming  PHELPS, Michael     USA    Men
# 27252  2008  Beijing  Aquatics   Swimming  PHELPS, Michael     USA    Men
# 27258  2008  Beijing  Aquatics   Swimming  PHELPS, Michael     USA    Men
# 27264  2008  Beijing  Aquatics   Swimming  PHELPS, Michael     USA    Men
# ...

# %%
len(df[df['Athlete'] == 'PHELPS, Michael'])
# Out:
# 22

# %%
18 Gold
2 Silver
2 Bronze

# %%
temp = df[df['Year'] == 2012]

# %%
temp[temp["Medal"] == "Gold"]
# Out:
#        Year    City          Sport           Discipline  \
# 29216  2012  London       Aquatics               Diving
# 29219  2012  London       Aquatics               Diving
# 29222  2012  London       Aquatics               Diving
# 29225  2012  London       Aquatics               Diving
# 29228  2012  London       Aquatics               Diving
# 29229  2012  London       Aquatics               Diving
# 29234  2012  London       Aquatics               Diving
# 29235  2012  London       Aquatics               Diving
# 29240  2012  London       Aquatics               Diving
# 29241  2012  London       Aquatics               Diving
# 29246  2012  London       Aquatics               Diving
# 29247  2012  London       Aquatics               Diving
# 29252  2012  London       Aquatics    Marathon swimming
# 29255  2012  London       Aquatics    Marathon swimming
# 29258  2012  London       Aquatics             Swimming
# 29261  2012  London       Aquatics             Swimming
# ...

# %%
temp = df[df['Country'] == 'IND']

# %%
temp
# Out:
#        Year         City          Sport           Discipline  \
# 241    1900        Paris      Athletics            Athletics
# 244    1900        Paris      Athletics            Athletics
# 5512   1928    Amsterdam         Hockey               Hockey
# 5513   1928    Amsterdam         Hockey               Hockey
# 5514   1928    Amsterdam         Hockey               Hockey
# 5515   1928    Amsterdam         Hockey               Hockey
# 5516   1928    Amsterdam         Hockey               Hockey
# 5517   1928    Amsterdam         Hockey               Hockey
# 5518   1928    Amsterdam         Hockey               Hockey
# 5519   1928    Amsterdam         Hockey               Hockey
# 5520   1928    Amsterdam         Hockey               Hockey
# 5521   1928    Amsterdam         Hockey               Hockey
# 5522   1928    Amsterdam         Hockey               Hockey
# 5523   1928    Amsterdam         Hockey               Hockey
# ...
