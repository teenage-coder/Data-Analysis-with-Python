# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
df = pd.read_csv("gdp.csv")

# %%
df.head()
# Out:
#            Country Code  Population  GDP per Capita
# 0      Afghanistan  AFG  32526562.0      594.323081
# 1          Albania  ALB   2889167.0     3945.217582
# 2          Algeria  ALG  39666519.0     4206.031232
# 3  American Samoa*  ASA     55538.0             NaN
# 4          Andorra  AND     70473.0             NaN

# %%
df.isnull().sum()
# Out:
# Country            0
# Code               0
# Population         5
# GDP per Capita    25
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Country           0
# Code              0
# Population        0
# GDP per Capita    0
# dtype: int64

# %%
df.head(10)
# Out:
#                 Country Code  Population  GDP per Capita
# 0           Afghanistan  AFG  32526562.0      594.323081
# 1               Albania  ALB   2889167.0     3945.217582
# 2               Algeria  ALG  39666519.0     4206.031232
# 5                Angola  ANG  25021974.0     4101.472152
# 6   Antigua and Barbuda  ANT     91818.0    13714.731962
# 7             Argentina  ARG  43416755.0    13431.878340
# 8               Armenia  ARM   3017712.0     3489.127690
# 10            Australia  AUS  23781169.0    56310.962993
# 11              Austria  AUT   8611088.0    43774.985174
# 12           Azerbaijan  AZE   9651349.0     5496.344640

# %%
top_10_population = df.sort_values(by = 'Population', ascending = False).head(10)

# %%
top_10_population[['Country','Population']]
# Out:
#            Country    Population
# 40           China  1.371220e+09
# 84           India  1.311051e+09
# 191  United States  3.214188e+08
# 85       Indonesia  2.575638e+08
# 26          Brazil  2.078475e+08
# 137       Pakistan  1.889249e+08
# 134        Nigeria  1.822020e+08
# 15      Bangladesh  1.609956e+08
# 150         Russia  1.440968e+08
# 118         Mexico  1.270172e+08

# %%
top_10_population[['Country','Population']].values
# Out:
# array([['China', 1371220000.0],
#        ['India', 1311050527.0],
#        ['United States', 321418820.0],
#        ['Indonesia', 257563815.0],
#        ['Brazil', 207847528.0],
#        ['Pakistan', 188924874.0],
#        ['Nigeria', 182201962.0],
#        ['Bangladesh', 160995642.0],
#        ['Russia', 144096812.0],
#        ['Mexico', 127017224.0]], dtype=object)

# %%
x = top_10_population['Country'].values
y = top_10_population['Population'].values

# %%
plt.plot(x,y)
plt.xlabel ("Countries")
plt.ylabel ("Population")
plt.title ("Population Analysis of top 10 Countries")

plt.show()

# %%
df.sort_values(by = 'GDP per Capita', ascending = False).head(10)
# Out:
#            Country Code   Population  GDP per Capita
# 108     Luxembourg  LUX     569676.0   101449.968168
# 175    Switzerland  SUI    8286976.0    80945.079219
# 135         Norway  NOR    5195921.0    74400.369777
# 148          Qatar  QAT    2235355.0    73653.394435
# 88         Ireland  IRL    4640703.0    61133.672427
# 10       Australia  AUS   23781169.0    56310.962993
# 191  United States  USA  321418820.0    56115.718426
# 163      Singapore  SIN    5535002.0    52888.744672
# 52         Denmark  DEN    5676002.0    51989.293471
# 174         Sweden  SWE    9798871.0    50579.673649

# %%
df.sort_values(by = 'GDP per Capita', ascending = True).head(10)
# Out:
#                       Country Code  Population  GDP per Capita
# 31                    Burundi  BDI  11178921.0      277.068309
# 37   Central African Republic  CAF   4900274.0      323.201674
# 133                     Niger  NIG  19899120.0      358.958152
# 111                    Malawi  MAW  17215232.0      371.985748
# 110                Madagascar  MAD  24235390.0      401.836006
# 104                   Liberia  LBR   4503438.0      455.873935
# 44             Congo, Dem Rep  COD  77266814.0      456.052741
# 68                     Gambia  GAM   1990924.0      471.537195
# 124                Mozambique  MOZ  27977863.0      529.242556
# 76                     Guinea  GUI  12608590.0      531.320595

# %% [markdown]
# # (GDP / Population) = GDP per Capita

# %%
gdp = gdp_per_capita * population

# %%
df['Population'] * df['GDP per Capita']
# Out:
# 0      1.933129e+10
# 1      1.139839e+10
# 2      1.668386e+11
# 5      1.026269e+11
# 6      1.259259e+09
# 7      5.831686e+11
# 8      1.052918e+10
# 10     1.339141e+12
# 11     3.769502e+11
# 12     5.304714e+10
# 13     8.853519e+09
# 14     3.112585e+10
# 15     1.950787e+11
# 16     4.385250e+09
# 17     5.460896e+10
# 18     4.550857e+11
# 19     1.752861e+09
# 21     8.290987e+09
# 22     2.057948e+09
# 23     3.299768e+10
# 24     1.619172e+10
# 25     1.438972e+10
# 26     1.774725e+12
# 28     1.293039e+10
# 29     5.019912e+10
# 30     1.067820e+10
# 31     3.097325e+09
# 32     1.804995e+10
# 33     2.841595e+10
# 34     1.550537e+12
#            ...
# 167    5.925000e+09
# 168    3.145719e+11
# 169    1.199057e+12
# 170    8.231617e+10
# 171    9.715612e+10
# 172    5.150291e+09
# 173    4.118488e+09
# 174    4.956237e+11
# 175    6.707899e+11
# 178    7.853450e+09
# 179    4.699917e+10
# 180    3.951680e+11
# 181    4.087904e+09
# 182    4.351424e+08
# ...

# %%
df
# Out:
#                     Country Code   Population  GDP per Capita
# 0               Afghanistan  AFG   32526562.0      594.323081
# 1                   Albania  ALB    2889167.0     3945.217582
# 2                   Algeria  ALG   39666519.0     4206.031232
# 5                    Angola  ANG   25021974.0     4101.472152
# 6       Antigua and Barbuda  ANT      91818.0    13714.731962
# 7                 Argentina  ARG   43416755.0    13431.878340
# 8                   Armenia  ARM    3017712.0     3489.127690
# 10                Australia  AUS   23781169.0    56310.962993
# 11                  Austria  AUT    8611088.0    43774.985174
# 12               Azerbaijan  AZE    9651349.0     5496.344640
# 13                  Bahamas  BAH     388019.0    22817.230857
# 14                  Bahrain  BRN    1377237.0    22600.214098
# 15               Bangladesh  BAN  160995642.0     1211.701531
# 16                 Barbados  BAR     284215.0    15429.340464
# ...
